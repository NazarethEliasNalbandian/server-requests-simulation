# %%
# !pip install lckr_jupyterlab_variableinspector
# Out:
# Requirement already satisfied: lckr_jupyterlab_variableinspector in c:\users\nazar\anaconda3\lib\site-packages (3.1.0)

# %%
from datetime import timedelta
import random
from scipy.stats import pareto
from scipy.stats import expon
from scipy.stats import lognorm
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
TPLL = None
TPS_GET = None
TPS_POST = None
NT_GET = None
NT_POST = None
STLL_GET = None
STLL_POST = None
STS_GET = None
STS_POST = None
STO_GET = None
STO_POST = None
STA_GET = None
STA_POST = None
CS = None
CC = None
T = None
TF = None
ITO_GET = None
ITO_POST = None
N = None
M = None
HV = None
resultados = []

# %%
def CI():
    global TPLL, TPS_GET, TPS_POST
    global NT_GET, NT_POST
    global STLL_GET, STLL_POST
    global STS_GET, STS_POST
    global STO_GET, STO_POST
    global CS, CC
    global T, TF
    global ITO_GET, ITO_POST
    global STA_GET, STA_POST
    global HV
    global Ti

    Ti = timedelta(hours=6)

    HV = timedelta.max

    TPLL = timedelta(hours=6)
    TPLL_POST = timedelta(hours=6)
    TPLL_GET = timedelta(hours=6)
    TPS_GET = [HV for _ in range(N)]
    TPS_POST = [HV for _ in range(M)]

    NT_GET = 0
    NT_POST = 0

    STLL_GET = timedelta(0)
    STLL_POST = timedelta(0)
    STS_GET = timedelta(0)
    STS_POST = timedelta(0)
    STA_GET = [timedelta(0) for _ in range(N)]
    STA_POST = [timedelta(0) for _ in range(M)]
    
    STO_GET = [timedelta(0) for _ in range(N)]
    STO_POST = [timedelta(0) for _ in range(M)]

    ITO_GET = [timedelta(hours=6) for _ in range(N)]
    ITO_POST = [timedelta(hours=6) for _ in range(M)]

    CS = 0
    CC = 0
    
    T = timedelta(0)
    TF = timedelta(hours=23)

# %%
def loggear(texto):
    with open('log.txt', 'a') as f:
        f.write(texto + '\n')

# %%
def MENOR_TPS(TPS):
    if not TPS:
        raise ValueError("El vector TPS está vacío.")

    indice_min = 0
    valor_min = TPS[0]

    for i in range(1, len(TPS)):
        if TPS[i] < valor_min:
            valor_min = TPS[i]
            indice_min = i

    return indice_min

# %%
def IA_MAÑANA():
    b = 112.66
    loc = -7966
    scale = 7967

    valor_milisegundos = pareto.rvs(b, loc=loc, scale=scale)

    # print(f"IA_MAÑANA retorno: {valor_milisegundos}")

    return timedelta(milliseconds=valor_milisegundos)

# %%
def IA_TARDE():
    b = 58.7
    loc = -2467.2
    scale = 2468.2

    valor_milisegundos = pareto.rvs(b, loc=loc, scale=scale)

    # print(f"IA_TARDE retorno: {valor_milisegundos}")

    return timedelta(milliseconds=valor_milisegundos)

# %%
def IA_NOCHE():
    loc = 1
    scale = 107.37

    valor_milisegundos = expon.rvs(loc=loc, scale=scale)

    # print(f"IA_NOCHE retorno: {valor_milisegundos}")

    return timedelta(milliseconds=valor_milisegundos)

# %%
def TA_SIMPLES():
    global TA_Simples

    s = 0.1
    loc = -229.95
    scale = 512.89

    valor_milisegundos = lognorm.rvs(s, loc=loc, scale=scale)

    TA_Simples = timedelta(milliseconds=valor_milisegundos)

# %%
def TA_COMPLEJAS():
    global TA_Complejas

    s = 0.1
    loc = -398.85
    scale = 1544.11

    valor_milisegundos = lognorm.rvs(s, loc=loc, scale=scale)

    TA_Complejas = timedelta(milliseconds=valor_milisegundos)

# %%
def SALIDA_GET(I):
    global T, TPS_GET, CS, ITO_GET, TA_Simples, STS_GET, N, STA_GET

    STS_GET = STS_GET + T
    
    T = TPS_GET[I]

    #loggear(f"Salida GET en el servidor {I} en instante: {T}")
    CS -= 1

    # print(f"CS luego de la salida: {CS}")

    if CS >= N:
        TA_SIMPLES()
        STA_GET[I] = STA_GET[I] + TA_Simples
        TPS_GET[I] = T + TA_Simples
    else:
        ITO_GET[I] = T

        #loggear(f"INICIO TIEMPO OCIOSO DE PUESTO GET {I}: {ITO_GET[I]}")
        TPS_GET[I] = timedelta.max

    # print(f"TPS_GET del puesto {I}: {TPS_GET[I]}")

# %%
def SALIDA_POST(J):
    global T, TPS_POST, CC, ITO_POST, TA_Complejas, STS_POST, M, STA_POST

    STS_POST = STS_POST + T

    T = TPS_POST[J]

    #loggear(f"Salida POST en el servidor {J} en instante: {T}")
    
    CC -= 1

    # print(f"CC luego de la salida: {CC}")

    if CC >= M:
        TA_COMPLEJAS()
        STA_POST[J] = STA_POST[J] + TA_Complejas
        TPS_POST[J] = T + TA_Complejas
    else:
        ITO_POST[J] = T

        #loggear(f"INICIO TIEMPO OCIOSO DE PUESTO POST {J}: {ITO_POST[J]}")
        TPS_POST[J] = timedelta.max
        
    # print(f"TPS_POST del puesto {J}: {TPS_POST[J]}")

# %%
def BUSCAR_PUESTO_GET():
    global TPS_GET, STO_GET

    mejor_indice = -1

    for i in range(len(TPS_GET)):
        if TPS_GET[i] == HV:
            mejor_indice = i
            return mejor_indice
            
    return mejor_indice

# %%
def ATENCION_GET():
    global CS, STO_GET, T, ITO_GET, TPS_GET, TA_Simples, N, STA_GET

    if CS <= N:
        X = BUSCAR_PUESTO_GET()

        #loggear(f"ITO_GET DE PUESTO {X}: {ITO_GET[X]}")

        #loggear(f"INTERVALO DE TIEMPO OCIOSO DE PUESTO {X}: {T - ITO_GET[X]}")

        STO_GET[X] = STO_GET[X] + (T - ITO_GET[X])

        #loggear(f"SUMATORIA TIEMPO OCIOSO DE PUESTO GET {X}: {STO_GET[X]}")

        TA_SIMPLES()

        STA_GET[X] = STA_GET[X] + TA_Simples

        TPS_GET[X] = T + TA_Simples

# %%
def BUSCAR_PUESTO_POST():
    global TPS_POST, STO_POST
    
    mejor_indice = -1

    for i in range(len(TPS_POST)):
        if TPS_POST[i] == HV:
            mejor_indice = i
            return mejor_indice

    return mejor_indice

# %%
def ATENCION_POST():
    #pdb.set_trace()
    global CC, STO_POST, T, ITO_POST, TPS_POST, TA_Complejas, M, STA_POST

    if CC <= M:
        
        X = BUSCAR_PUESTO_POST()

        #loggear(f"ITO_POST DE PUESTO {X}: {ITO_POST[X]}")

        #loggear(f"INTERVALO DE TIEMPO OCIOSO DE PUESTO {X}: {T - ITO_POST[X]}")

        STO_POST[X] = STO_POST[X] + (T - ITO_POST[X])

        #loggear(f"SUMATORIA TIEMPO OCIOSO DE PUESTO POST {X}: {STO_POST[X]}")

        TA_COMPLEJAS()

        STA_POST[X] = STA_POST[X] + TA_Complejas

        TPS_POST[X] = T + TA_Complejas

# %%
def LLEGADA():
    #pdb.set_trace()
    global T, TPLL, NT_POST, NT_GET, CC, CS, STLL_POST, STLL_GET, TPLL_POST, TPLL_GET

    R = random.random()

    T = TPLL

    #loggear(f"Instante: {T}")

    hora_actual = T.seconds // 3600

    if 6 <= hora_actual <= 10:
        IA = IA_MAÑANA()
    elif 11 <= hora_actual <= 17:
        IA = IA_TARDE()
    elif 18 <= hora_actual <= 23:
        IA = IA_NOCHE()
    else:
        IA = timedelta.max

    
    TPLL = T + IA

    #loggear(f"TPLL: {TPLL}")

    if R <= 0.7:
        NT_POST+=1
        CC += 1
        STLL_POST = STLL_POST + T

        #loggear(f"CC luego de la llegada POST: {CC}")
        ATENCION_POST()
    else:
        NT_GET+=1
        CS += 1
        STLL_GET = STLL_GET + T

        #loggear(f"CS luego de la llegada GET: {CS}")
        ATENCION_GET()

# %%
def RESULTADOS():
    global TRP_Complejas, TRP_Simples, PTO_GET, PTO_POST
    global STLL_POST, STLL_GET, STS_POST, STS_GET, NT_POST, NT_GET
    global STO_GET, STO_POST, STA_GET, STA_POST, N, M, Ti

    # Calcular TRP_Complejas y TRP_Simples en milisegundos (entero)
    if NT_POST > 0:
        TRP_Complejas = int(((STS_POST - STLL_POST).total_seconds() * 1000)/NT_POST)
    else:
        TRP_Complejas = 0

    if NT_GET > 0:
         TRP_Simples = int(((STS_GET - STLL_GET).total_seconds() * 1000)/NT_GET)
    else:
         TRP_Simples = 0

    PTO_GET = [0 for _ in range(N)]
    PTO_POST = [0 for _ in range(M)]

    for i in range(N):
        total_sec = (T - Ti).total_seconds()
        if total_sec != 0:
            PTO_GET[i] = round((STO_GET[i].total_seconds() / total_sec)*100, 2)
        else:
            print(f"ALGO RARO PASO CON {total_sec}")
            PTO_GET[i] = 0

    for j in range(M):
        total_sec = (T - Ti).total_seconds()
        if total_sec != 0:
            PTO_POST[j] = round((STO_POST[j].total_seconds() * 100) / total_sec, 2)
        else:
            print(f"ALGO RARO PASO CON {total_sec}")
            PTO_POST[j] = 0

# %%
def GENERAR_DATAFRAME():
    global N, M, TRP_Simples, TRP_Complejas, PTO_GET, PTO_POST

    # Crear diccionario base
    datos = {
        'N': [N],
        'M': [M],
        'TRP_Simples': [TRP_Simples],
        'TRP_Complejas': [TRP_Complejas],
    }

    # Cargar porcentajes GET (hasta 4 puestos)
    for i in range(5):
        if i < len(PTO_GET):
            datos[f'PTO_GET_{i+1}'] = [PTO_GET[i]]
        else:
            datos[f'PTO_GET_{i+1}'] = [None]

    # Cargar porcentajes POST (hasta 13 puestos)
    for i in range(20):
        if i < len(PTO_POST):
            datos[f'PTO_POST_{i+1}'] = [PTO_POST[i]]
        else:
            datos[f'PTO_POST_{i+1}'] = [None]

    # Crear nuevo DataFrame
    nuevo_df = pd.DataFrame(datos)

    # Intentar cargar archivo existente y agregar fila
    try:
        df_existente = pd.read_csv("resultados.csv")
        df_final = pd.concat([df_existente, nuevo_df], ignore_index=True)
    except FileNotFoundError:
        df_final = nuevo_df

    # Guardar el DataFrame actualizado
    df_final.to_csv("resultados.csv", index=False)

    return nuevo_df

# %%
def EJECUCION():
    # pdb.set_trace()
    global T, TPLL, TPS_GET, TPS_POST, HV, CS, CC
    
    while True:
        I = MENOR_TPS(TPS_GET)
        J = MENOR_TPS(TPS_POST)

        if TPS_GET[I] <= TPS_POST[J]:
            if TPS_GET[I] <= TPLL:
                SALIDA_GET(I)
            else:
                LLEGADA()
        else:
            if TPS_POST[J] <= TPLL:
                SALIDA_POST(J)
            else:
                LLEGADA()

        if not (T <= TF):
            break

    # print(f'CS: {CS}')
    # print(f'CC: {CC}')
    
    if not (CS == 0 and CC == 0):
         TPLL = HV
         EJECUCION()

# %%
def SIMULACION():
    CI()

    EJECUCION()
        
    RESULTADOS()    
    ## print(GENERAR_DATAFRAME().head())

# %%
global N, M

# %%
def graficar():
    import numpy as np

    # Definir los bins para rangos de 10 en 10
    bins = list(range(0, 101, 10))  # [0, 10, 20, ..., 100]
    labels = [f'{bins[i]}-{bins[i+1]}%' for i in range(len(bins)-1)]
    labels[-1] = '90-100%'  # aseguramos que el último sea cerrado a derecha

    # Función para contar cuántos valores caen en cada rango
    def contar_por_rango(valores):
        conteo = [0] * (len(bins) - 1)
        for v in valores:
            for i in range(len(bins) - 1):
                if bins[i] <= v < bins[i+1] or (i == len(bins)-2 and v == bins[i+1]):
                    conteo[i] += 1
                    break
        return conteo

    # Calcular frecuencias para GET y POST
    frecuencias_get = contar_por_rango(PTO_GET)
    frecuencias_post = contar_por_rango(PTO_POST)

    # Graficar GET
    plt.figure(figsize=(10, 5))
    plt.bar(labels, frecuencias_get, color='skyblue')
    plt.title(f'Cantidad de puestos GET por rango de % de tiempo ocioso (N = {N})')
    plt.xlabel('Rango de % de tiempo ocioso')
    plt.ylabel('Cantidad de puestos')
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

    # Graficar POST
    plt.figure(figsize=(10, 5))
    plt.bar(labels, frecuencias_post, color='orange')
    plt.title(f'Cantidad de puestos POST por rango de % de tiempo ocioso (M = {M})')
    plt.xlabel('Rango de % de tiempo ocioso')
    plt.ylabel('Cantidad de puestos')
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %%
def RUN(n,m):
        global N, M
    
        N = n
        M = m
        
        SIMULACION()

        if len(PTO_GET) > 0:
            prom_ocioso_get = sum(PTO_GET) / len(PTO_GET)
        else:
            prom_ocioso_get = 0

        if len(PTO_POST) > 0:
            prom_ocioso_post = sum(PTO_POST) / len(PTO_POST)
        else:
            prom_ocioso_post = 0

        resultados.append({
            "N": N,
            "M": M,
            "PPTO_GET": prom_ocioso_get,
            "PPTO_POST": prom_ocioso_post,
            "TRP_Simples": TRP_Simples,
            "TRP_Complejas": TRP_Complejas
        })

        graficar()

        GENERAR_DATAFRAME()

        df_resultados = pd.DataFrame(resultados)
        print(df_resultados)

# %%
# valores_N = [2, 3, 4]
# valores_M = [9,11,12,13]

# valores_N = [7,8,9,10]
# valores_M = [24,25]

# for n in valores_N:
#    for m in valores_M:
#        RUN(n,m)

# %%
RUN(5,19) # ACTUAL
RUN(2,18) # INTERMEDIO
RUN(3,20) # OPTIMO
# Out:
#    N   M  PPTO_GET  PPTO_POST  TRP_Simples  TRP_Complejas
# 0  5  19    72.284  31.215263          256           1601
# C:\Users\nazar\AppData\Local\Temp\ipykernel_18972\1551241561.py:32: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_final = pd.concat([df_existente, nuevo_df], ignore_index=True)
#    N   M  PPTO_GET  PPTO_POST  TRP_Simples  TRP_Complejas
# 0  5  19    72.284  31.215263          256           1601
# 1  2  18    30.680  27.359444         2134         190500
#    N   M   PPTO_GET  PPTO_POST  TRP_Simples  TRP_Complejas
# 0  5  19  72.284000  31.215263          256           1601
# 1  2  18  30.680000  27.359444         2134         190500
# 2  3  20  53.833333  34.097500          295           1264
# C:\Users\nazar\AppData\Local\Temp\ipykernel_18972\1551241561.py:32: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_final = pd.concat([df_existente, nuevo_df], ignore_index=True)

# %%
df_res = pd.read_csv("resultados.csv")

df_res = df_res.sort_values(by=["N", "M"], ascending=[True, True]).reset_index(drop=True)

# %%
# Columnas de tiempo ocioso
pto_get_cols = [f'PTO_GET_{i+1}' for i in range(4)]
pto_post_cols = [f'PTO_POST_{i+1}' for i in range(13)]

# Función para contar por rangos
def contar_rangos(row, columnas):
    valores = row[columnas].dropna()
    return pd.Series([
        ((valores >= 0) & (valores < 25)).sum(),
        ((valores >= 25) & (valores < 50)).sum(),
        ((valores >= 50) & (valores < 75)).sum(),
        ((valores >= 75) & (valores <= 100)).sum()
    ], index=["PTO_0_25", "PTO_25_50", "PTO_50_75", "PTO_75_100"])

# --- df_get ---

# Asegurar columnas necesarias
df_get = df_res[['N', 'TRP_Simples'] + pto_get_cols].sort_values(by="N").reset_index(drop=True)
df_get["PTO_GET_MEDIANA"] = df_get[pto_get_cols].median(axis=1)

# Agregar columnas por rangos
df_get_rangos = df_get.apply(lambda row: contar_rangos(row, pto_get_cols), axis=1)
df_get = pd.concat([df_get[['N', 'TRP_Simples', 'PTO_GET_MEDIANA']], df_get_rangos], axis=1)

# --- df_post ---

# Asegurar columnas necesarias
df_post = df_res[['M', 'TRP_Complejas'] + pto_post_cols].sort_values(by="M").reset_index(drop=True)
df_post["PTO_POST_MEDIANA"] = df_post[pto_post_cols].median(axis=1)

# Agregar columnas por rangos
df_post_rangos = df_post.apply(lambda row: contar_rangos(row, pto_post_cols), axis=1)
df_post = pd.concat([df_post[['M', 'TRP_Complejas', 'PTO_POST_MEDIANA']], df_post_rangos], axis=1)

# Mostrar
display(df_get)
display(df_post)
# Out:
#    N  TRP_Simples  PTO_GET_MEDIANA  PTO_0_25  PTO_25_50  PTO_50_75  PTO_75_100
# 0  2         2134           30.680         0          2          0           0
# 1  3          295           54.120         0          1          2           0
# 2  5          256           68.315         0          1          1           2
#     M  TRP_Complejas  PTO_POST_MEDIANA  PTO_0_25  PTO_25_50  PTO_50_75  \
# 0  18         190500             16.44         9          4          0
# 1  19           1601             18.04         8          5          0
# 2  20           1264             18.92         8          5          0
#
#    PTO_75_100
# 0           0
# 1           0
# 2           0

# %%
display(df_res)
# Out:
#    N   M  TRP_Simples  TRP_Complejas  PTO_GET_1  PTO_GET_2  PTO_GET_3  \
# 0  2  18         2134         190500      25.31      36.05        NaN
# 1  3  20          295           1264      38.66      54.12      68.72
# 2  5  19          256           1601      43.34      60.49      76.14
#
#    PTO_GET_4  PTO_GET_5  PTO_POST_1  PTO_POST_2  PTO_POST_3  PTO_POST_4  \
# 0        NaN        NaN        5.59        6.63        7.91        9.51
# 1        NaN        NaN        6.72        7.87        9.20       11.01
# 2      87.36      94.09        6.18        7.32        8.71       10.38
#
#    PTO_POST_5  PTO_POST_6  PTO_POST_7  PTO_POST_8  PTO_POST_9  PTO_POST_10  \
# 0       11.43       13.66       16.44       19.81       23.60        27.52
# 1       13.07       15.64       18.92       22.45       26.66        31.04
# 2       12.39       14.94       18.04       21.60       25.61        29.77
#
#    PTO_POST_11  PTO_POST_12  PTO_POST_13  PTO_POST_14  PTO_POST_15  \
# 0        31.66        35.80        39.71        43.33        46.41
# 1        35.72        40.28        44.76        48.96        52.79
# 2        34.39        38.77        43.03        46.86        50.17
#
#    PTO_POST_16  PTO_POST_17  PTO_POST_18  PTO_POST_19  PTO_POST_20  \
# 0        49.07        51.33        53.06          NaN          NaN
# 1        56.01        58.97        61.47        60.78        59.63
# 2        53.12        55.44        57.25        59.12          NaN
#
#    PTO_POST_21  PTO_POST_22  PTO_POST_23  PTO_POST_24  PTO_POST_25
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
